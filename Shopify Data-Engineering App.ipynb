# %% [markdown]
# ## Scoping

# %%
import pandas as pd
import matplotlib as mb
import matplotlib.pyplot as plt
from bqplot import pyplot as pp
import numpy as np

# %%
df = pd.read_csv("Shopify Database - Shopify Data.csv")

# %%
df.head()
# Out:
#    No       Web Site Website IP Address Web Hosting Company / IP Owner  \
# 0   1  myshopify.com       23.227.38.64                   Shopify, Inc
# 1   2  colourpop.com       23.227.38.64                   Shopify, Inc
# 2   3     cupshe.com       23.227.38.64                   Shopify, Inc
# 3   4   allbirds.com       23.227.38.64                   Shopify, Inc
# 4   5  jbhifi.com.au       23.227.38.32                   Shopify, Inc
#
#   Web Hosting / Server IP Location Web Hosting City World Site Popular Rating  \
# 0                           Canada           Ottawa                      # 78
# 1                           Canada           Ottawa                   # 2,787
# 2                           Canada           Ottawa                   # 3,917
# 3                           Canada           Ottawa                   # 4,707
# 4                           Canada           Ottawa                   # 5,108
#
#   World Site Popular Rating (MyIP)  Alexa Global Ranking     TLD  \
# ...

# %%
np.plot(np.array(df['Web Site']), np.array(df['Alexa Global Ranking']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-da36208e36cf> in <module>()
# ----> 1 np.plot(np.array(df['Web Site']), np.array(df['Alexa Global Ranking']))
#
# AttributeError: module 'numpy' has no attribute 'plot'

# %%
df_2 = pd.read_csv('products_db/kith_products.csv ')

# %%
df_2['SKU'].nunique()
# Out:
# 3078
